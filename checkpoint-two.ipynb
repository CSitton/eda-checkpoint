# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:https://www.kaggle.com/datasets/vesuvius13/serial-killers-dataset
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 

small_df = pd.read_csv("Lessthan_5_victim_count.csv")
mid_df = pd.read_csv("5_to_14_victim_count.csv")
mod_df = pd.read_csv("15_to_30_victim_count.csv")
large_df = pd.read_csv("Highest_victim_count.csv")

#all data sets have the same info, difference is the number of victims. To understand a general sense I will look at the large dataset 
large_df.info()
large_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              34 non-null     object
#  1   Country           34 non-null     object
#  2   Years active      34 non-null     object
#  3   Proven victims    34 non-null     int64
#  4   Possible victims  34 non-null     object
#  5   Notes             34 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.7+ KB
#                      Name                                  Country  \
# 0           Luis Garavito         Colombia\r\nEcuador\r\nVenezuela
# 1             Pedro López              Colombia\r\nPeru\r\nEcuador
# 2             Javed Iqbal                                 Pakistan
# 3          Mikhail Popkov                                   Russia
# 4  Daniel Camargo Barbosa  Colombia\r\nEcuador\r\nBrazil (alleged)
#
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
large_df.describe()
# Out:
#        Proven victims
# count       34.000000
# mean        52.764706
# std         24.601132
# min         32.000000
# 25%         35.250000
# 50%         46.500000
# 75%         59.500000
# max        138.000000

# %%
large_df.head(20)
# Out:
#                        Name                                  Country  \
# 0             Luis Garavito         Colombia\r\nEcuador\r\nVenezuela
# 1               Pedro López              Colombia\r\nPeru\r\nEcuador
# 2               Javed Iqbal                                 Pakistan
# 3            Mikhail Popkov                                   Russia
# 4    Daniel Camargo Barbosa  Colombia\r\nEcuador\r\nBrazil (alleged)
# 5     Pedro Rodrigues Filho                                   Brazil
# 6     Kampatimar Shankariya                                    India
# 7               Yang Xinhai                                    China
# 8             Samuel Little                            United States
# 9            Giuseppe Greco                                    Italy
# 10         Andrei Chikatilo                             Soviet Union
# 11       Anatoly Onoprienko                  Soviet Union\r\nUkraine
# 12           Ivan Maleshoff                             Soviet Union
# ...

# %%
large_df.columns
# identifying the column names
# Out:
# Index(['Name', 'Country', 'Years active', 'Proven victims', 'Possible victims',
#        'Notes'],
#       dtype='object')

# %%
large_df.isnull().sum()
#no null info
# Out:
# Name                0
# Country             0
# Years active        0
# Proven victims      0
# Possible victims    0
# Notes               0
# dtype: int64

# %%
large_df.shape[1]
#column number
# Out:
# 6

# %%
large_df.shape[0]
#row number
# Out:
# 34

# %%
large_df.groupby('Name')[['Proven victims','Name']].head()
#Practicing grouping the data together
# Out:
#     Proven victims                           Name
# 0              138                  Luis Garavito
# 1              110                    Pedro López
# 2              100                    Javed Iqbal
# 3               83                 Mikhail Popkov
# 4               72         Daniel Camargo Barbosa
# 5               71          Pedro Rodrigues Filho
# 6               70          Kampatimar Shankariya
# 7               67                    Yang Xinhai
# 8               60                  Samuel Little
# 9               58                 Giuseppe Greco
# 10              53               Andrei Chikatilo
# 11              52             Anatoly Onoprienko
# 12              50                 Ivan Maleshoff
# 13              50        Florisvaldo de Oliveira
# 14              49                  Willy Pickton
# 15              49                   Gary Ridgway
# 16              48           Alexander Pichushkin
# 17              45                     Wang Qiang
# ...

# %%
maxValues = large_df[['Proven victims', 'Possible victims']].max()

print(maxValues)
# Out:
# Proven victims      138
# Possible victims    ~39
# dtype: object

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
large_df.hist('Proven victims')
plt.show()

#analyze the range in the number of proven victims

# %%
large_df['Country'].value_counts().plot(kind='bar');
#wanted to visualize the highest country
# Out:
# ) missing from current font.te-packages\IPython\core\events.py:89: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.te-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# 2. Do you have any concerns about your dataset?
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
#
# 1. The most surprising thing was just the large number involved in victims
# 2. My main concern is the 4 data sets, figuring out the best way to go about forming my information
# 3. There wasn't null info in the large data, so may be pleasantly surprised when cleaning data.
